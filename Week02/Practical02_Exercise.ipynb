# %% [markdown]
# # Practical 02 Exercises

# %% [markdown]
# Note: Only the full trajectories will be displayed for Exercise 2 and 3

# %%
import numpy as np
from Practical02_Support.Renderer import *
from ece4078.Utility import StartMeshcat

# %%
vis = StartMeshcat()
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/
# Meshcat URL if you are on local machine: <a href='http://127.0.0.1:7000/static/' target='_blank'>http://127.0.0.1:7000/static/</a>

# %% [markdown]
# # Coding exercises

# %% [markdown]
# # Exercise 1 (2pts): Determine the Location of the Rear Wheel
#
# ![bicycle.png](https://i.imgur.com/zIhei8A.png)
#
# Given the known 2D location of the centre of the front wheel of the bicycle ($x_f$, $y_f$), determine the location of the centre of the rear wheel ($x, y$) in the world frame.
#
# **Input**:
# - 1D array of shape 2x1 with the location of the front wheel (front_wheel_loc)
# - Orientation of the bicycle in radians (theta)
# - Bicycle length (length)
#
# **Output**:
# - 1D array of shape 2x1 with the location of the rear wheel in the world frame (values should not be rounded)

# %%
def get_rear_wheel_location(front_wheel_loc=np.zeros(2), theta=0, length=0):
    rear_wheel_loc = np.zeros(2)
    
    #TODO: Add your code here  ------------------------------------------
    
    #ENDTODO -----------------------------------------------------------
    
    return rear_wheel_loc

# %% [markdown]
# **Test your code**
#
# We have included a plot function ``display_bycicle_wheels`` to help you verify your answers. The function will display two frames, one to represent the rear wheel (red) and another to represent the front wheel (blue). Similarly, the function assumes that the steering angle $\delta$ is set to zero. Here is an example of how to use it:

# %%
front_wheel = np.ones(2)*2
theta_angle = 0
rear_wheel = get_rear_wheel_location(front_wheel_loc=front_wheel, theta=theta_angle, length=0.5)

display_bicycle_wheels(rear_wheel, front_wheel, theta=theta_angle)

# %% [markdown]
# As visual test cases, we recommend to consider:
#
# - Where should be the front wheel if $\theta=0$?
# - Where should be the front wheel if $\theta=\frac{\pi}{2}$?

# %% [markdown]
# ### Exercise 2 (3pts): Extend Bicycle Model to Consider Velocity and Steering Angle Rate as Inputs
#
# In the example of the bicycle model, the bicycle took as inputs velocity $v$ and steering angle $\delta$.
#
# We now want to modify our model so that it receives velocity $v$ and steering rate $\varphi$ as control inputs instead. With this new control input, the bicycle state is now defined by its 2D position $(x,y)$,  orientation ($\theta$) and steering angle ($\delta$).
#
# You are tasked with deriving the revised model to handle the modified inputs and using the new model to compute the bicycle state for a total of $max\_T$ iterations using this new control input.
#
# Your code should input a constant input velocity and steering rate at each time step.
#
# **Input**:
# - 1D array with the initial bicycle state $[x, y, \theta, \delta]$
# - Bicycle length (length)
# - Maximum number of iterations (max_t)
# - Input velocity ($v_i$)
# - Input Steering_rate (phi)
#
#
# **Output**:
# - Array of bicycle states of length max_t. Column order must be $[x, y, \theta, \delta]$ (values should not be rounded)

# %%
def get_bicycle_trajectory(initial_state = np.array([1, 1, 0, 0]), length=1, max_t=100, v=0, phi=0):
    
    dt = 0.02
    states = np.zeros((max_t+1, initial_state.shape[0]))
    states[0,:] = initial_state
    
    
    #TODO: Add your code here --------------------------------------------
    
    #ENDTODO -------------------------------------------------------------
        
    return states

# %% [markdown]
# **Test your code**
#
# We have included a rendering class to help you verify your answers. Here is an example of how to use it:

# %%
# Input parameters
initial_state=np.array([5, -5, np.pi/2, 0.1])
length=1
max_t=250
v_i=2.3
phi=0.2

trj = get_bicycle_trajectory(initial_state, length, max_t, v_i, phi)

vis.delete()
vis.Set2DView(scale = abs(initial_state[0]) + 1)
vis.mask_origin()
display_traj(vis, trj[:, :3], scale = 6)
display(vis.show_inline())
# Out:
# HBox(children=(Button(button_style='success', description='Play/Pause', layout=Layout(flex='1 1 0%', width='au…
# HTML(value='\n                <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; re…

# %% [markdown]
# As visual test cases, we recommend you to keep in mind that:
#
# - The bicycle should move in a straight line if $\delta=0$, and $\varphi=0$
# - The bicycle should move in a circular trajectory if $v \ne 0$, $\delta \ne 0$, and $\varphi=0$
# - The bicycle should move in a spiral trajectory if $v \ne 0$, and $\varphi\ne0$

# %% [markdown]
# ### Exercise 3 (2pts): Differential Drive Kinematic Model
#
# Let us consider a two-wheeled vehicle that has the rotation rate of the wheels as control inputs.
#
# ![diff_drive.png](https://i.imgur.com/IuNNzVB.png)
#
# Given the kinematic constraints that relate the wheel rotation rates to the linear and angular velocity of the PenguiPi robot:
#
# $$
# v=\frac{rw_1 + rw_2}{2}
# $$
# $$
# \omega=\frac{rw_1 - rw_2}{l}
# $$
#
# compute the state, i.e., $[x, y, \theta]$ of the PenguiPi robot for a total of $T_{max}$ iterations using this new control input.
#
# **Input**:
# - 1D array with the initial robot state $[x, y, \theta]$
# - Wheels width (length, l)
# - Wheels radius (wheel_radius, r)
# - Maximum number of iterations (max_t)
# - Rotation rate of the right wheel (right_rate)
# - Rotation rate of the left wheel (left_rate)
#
# **Output**:
# - Array of robot states of lenght max_t. Column order must be $[x, y, \theta]$ (values should not be rounded)

# %%
def get_penguipi_trajectory(initial_state = np.array([1, 1, 0]), length=1, wheel_radius=0.1,
                            right_rate=0, left_rate=0, max_t=100):
    
    dt = 0.1
    states = np.zeros((max_t+1, initial_state.shape[0]))
    states[0, :] = initial_state
    
    #TODO: Add your code here --------------------------------------------
    
    #ENDTODO -------------------------------------------------------------
        
    return states

# %% [markdown]
# **Test your code**
#
# We have included a rendering class to help you verify your answers. Here is an example of how to use it:

# %%
# Input parameters
initial_state=np.array([0, 0, np.pi/6])
length=1
wheel_radius=0.2
right_rate=10
left_rate=5
max_t=100

trj = get_penguipi_trajectory(initial_state, length, wheel_radius, right_rate, left_rate, max_t)

vis.delete()
vis.Set2DView(scale = 4)
vis.mask_origin()
display_traj(vis, trj[:, :3], scale = 6)
display(vis.show_inline())
# Out:
# HBox(children=(Button(button_style='success', description='Play/Pause', layout=Layout(flex='1 1 0%', width='au…
# HTML(value='\n                <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; re…

# %% [markdown]
# As visual test cases, we recommend you to keep in mind that:
#
# - The PenguiPi robot should move in a straight line if $w_1=w_2$
# - The PenguiPi robot should turn to the left if $w_1>w_2$ (the right wheel moves faster than the left wheel)
# - The PenguiPi robot should turn to the right if $w_1<w_2$ (the left wheel moves faster than the right wheel)

# %% [markdown]
# # Grading
# Test cases for giving marks:
# - q1: Assess the `get_rear_wheel_location` function (2 points)
# - q2: Assess the `get_bicycle_trajectory` function (3 points)
# - q3: Assess the `get_penguipi_trajectory` function (2 points)
#
# Hint: For question 2 and question 3, the body should have something like
# ```
# for i in range(max_t):
#     ...
#     states[i+1,:] = ...
# ```
# Because this is how the solution is constructed, the trajectory has `states[0, :] = initial_state` and the length of the trajectory should be equal to `max_t + 1`

# %%
import otter
grader = otter.Notebook(tests_dir = "Practical02_Support/tests")
grader.check_all()
# Out:
# q1 results:
#     q1 - 1 result:
#         Trying:
#             import sys
#         Expecting nothing
#         ok
#         Trying:
#             sys.stdout.write('skip '); r = np.array(get_rear_wheel_location(np.array([0., 0.]), theta=-np.pi/2, length=3)) # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         ok
#         Trying:
#             answer = np.array([0,  3])
#         Expecting nothing
#         ok
#         Trying:
#             np.all(np.isclose(r, answer))
#         Expecting:
#             True
#         **********************************************************************
#         Line 6, in q1 0
#         Failed example:
#             np.all(np.isclose(r, answer))
#         Expected:
#             True
#         Got:
#             False
#
#     q1 - 2 result:
#         Trying:
#             import sys
#         Expecting nothing
#         ok
#         Trying:
#             sys.stdout.write('skip '); r = np.array(get_rear_wheel_location(np.array([-2., 3.]), theta=np.pi/4, length=.5)) # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         ok
#         Trying:
#             answer = np.array([-2.35355339, 2.64644661])
#         Expecting nothing
#         ok
#         Trying:
#             np.all(np.isclose(r, answer))
#         Expecting:
#             True
#         **********************************************************************
#         Line 6, in q1 1
#         Failed example:
#             np.all(np.isclose(r, answer))
#         Expected:
#             True
#         Got:
#             False
#
#     q1 - 3 result:
#         Trying:
#             import sys
#         Expecting nothing
#         ok
#         Trying:
#             sys.stdout.write('skip '); r = np.array(get_rear_wheel_location(np.array([0., 10.]), theta=-np.pi/3, length=.1)) # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         ok
#         Trying:
#             answer = np.array([-0.05, 10.08660254])
#         Expecting nothing
#         ok
#         Trying:
#             np.all(np.isclose(r, answer))
#         Expecting:
#             True
#         **********************************************************************
#         Line 6, in q1 2
#         Failed example:
#             np.all(np.isclose(r, answer))
#         Expected:
#             True
#         Got:
#             False
#
# q2 results:
#     q2 - 1 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q2 0
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q2 0
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 0
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q2_file1.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q2 0
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 0
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 0
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 2 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q2 1
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q2 1
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 1
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q2_file2.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q2 1
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 1
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 1
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 3 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q2 2
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q2 2
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 2
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q2_file3.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q2 2
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 2
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 2
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 4 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q2 3
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q2 3
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 3
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q2_file4.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q2 3
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 3
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 3
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
# q3 results:
#     q3 - 1 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q3 0
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q3 0
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 0
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q3_file1.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q3 0
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 0
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 0
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q3 - 2 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q3 1
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q3 1
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 1
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q3_file2.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q3 1
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 1
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 1
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q3 - 3 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q3 2
#         Failed example:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[0]>", line 1, in <module>
#                 from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#             ImportError: cannot import name '_eval_timeout_print_str' from 'ece4078.Utility' (c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\site-packages\ece4078\Utility.py)
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q3 2
#         Failed example:
#             exec(_eval_timeout_print_str())
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[1]>", line 1, in <module>
#                 exec(_eval_timeout_print_str())
#             NameError: name '_eval_timeout_print_str' is not defined
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 2
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#             NameError: name 'eval_timeout_print' is not defined
#         Trying:
#             pickle_name_list = (["q3_file3.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         **********************************************************************
#         Line 7, in q3 2
#         Failed example:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[4]>", line 1, in <module>
#                 pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#             NameError: name 'enumerate_pickle' is not defined
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 2
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\Liew\AppData\Local\Programs\Python\Python310\lib\doctest.py", line 1350, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[6]>", line 1, in <module>
#                 for my_pickle in pickle_list:
#             NameError: name 'pickle_list' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 2
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
